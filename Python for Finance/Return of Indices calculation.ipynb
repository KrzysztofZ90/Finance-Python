# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data as wb
# Out:
# C:\Users\ForPeople\anaconda3\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
tickers = ['^GSPC', '^IXIC','^GDAXI','^FCHI']
ind_data = pd.DataFrame()

# %%
for i in tickers:
    ind_data[i] = wb.DataReader(i, data_source='yahoo', start='1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI        ^FCHI
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059  2257.000000
# 1997-01-03  748.030029  1310.680054  2863.260010  2282.800049
# 1997-01-06  747.650024  1316.400024  2890.199951  2306.699951
# 1997-01-07  753.229980  1327.729980  2876.340088  2301.699951
# 1997-01-08  748.409973  1320.349976  2904.080078  2331.600098

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15,6))
plt.show()

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1
ind_returns
# Out:
#                ^GSPC     ^IXIC    ^GDAXI     ^FCHI
# Date
# 1997-01-02       NaN       NaN       NaN       NaN
# 1997-01-03  0.014952  0.023409  0.015049  0.011431
# 1997-01-06 -0.000508  0.004364  0.009409  0.010470
# 1997-01-07  0.007463  0.008607 -0.004795 -0.002168
# 1997-01-08 -0.006399 -0.005558  0.009644  0.012990
# ...              ...       ...       ...       ...
# 2020-05-22  0.002354  0.004277  0.000718 -0.000200
# 2020-05-26  0.012289  0.001676  0.038901  0.036377
# 2020-05-27  0.014827  0.007724  0.013302  0.017910
# 2020-05-28 -0.002108 -0.004608  0.010589  0.017627
# 2020-05-29  0.004812  0.012902 -0.016491 -0.015918
#
# [5891 rows x 4 columns]

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC     0.079671
# ^IXIC     0.116915
# ^GDAXI    0.074725
# ^FCHI     0.047730
# dtype: float64

# %%
tickers = ['PG','^GSPC','^DJI']
data2 = pd.DataFrame()
for i in tickers:
    data2[i] = wb.DataReader(i, data_source='yahoo', start='2007-1-1')['Adj Close']

# %%
data2.head()
# Out:
#                    PG        ^GSPC          ^DJI
# Date
# 2007-01-03  43.147480  1416.599976  12474.519531
# 2007-01-04  42.819897  1418.339966  12480.690430
# 2007-01-05  42.452206  1409.709961  12398.009766
# 2007-01-08  42.545799  1412.839966  12423.490234
# 2007-01-09  42.438835  1412.109985  12416.599609

# %%
(data2 / data2.iloc[0]*100).plot(figsize=(15,6))
plt.show()
